# %% [markdown]
# This document is meant to describe the code archive I have built and use it to do some analysis of some Cosmic data.

# %% [markdown]
# ##### Pre/post processing and data merging
#
# The first part of the code are the two bash `uc2roppall` and `ppall` scripts that will process all of the data in a given file. These require the ropp functions applicable to function properly.
#
# `uc2roppall` will run a ucar to ropp script on all files with given properties and puts them in another folder.
#
# `ppall` postprocesses all files in a given folder and moves them into a new one.
#
# Both of these require some rewriting to work with any folder, but this is easy because you just have to change the file directory that is given in the first couple lines of the script.
#
# After all of the data is postprocessed then python needs to be activated and the function `mergeNetCDF4Directory` in `netCDF4utils` needs to be executed. There is documentation for this in the code file but I will supply it here:
#
# ```mergeNetCDF4Directory (string: directoryName, string: fileBeginning, string: outputFileName,
#                               character: separator = '|', array of strings: variables = DEFAULT_VARIABLES):
#         This function takes netCDF4 files in a directory with a certain fileBeginning and will merge them into a pandas dataframe this dataframe is then printed into a csv and will return the dataframe
#         The reason for this function:
#         When using ropp to post process occultations it outputs a file that is unwieldy and terrible, additionally it will only be one occultation at a time.
#         Pandas dataframes are much more user friendly and work with way more packages, so it is nicer to just have all the data in that form.
#         Also, it is far more useful to have all of the occultations in one bin so they can be analyzed together
#         Things to note:
#         Data should be indexed by occultation id by default
#         use something like this to select the row:
#             df.loc[df['occ_id'] == id]
#         ```

# %% [markdown]
# This function will save the merged csv to the file `outputFileName`. It will take all of the ropp files that are in a given directory, `directoryName`, and will merge them into one pandas dataframe, then it saves the file. `variables` is an array of strings that index which variables from the ropp files will be put into the merged file. `variables` has a default value that is defined in the code, however this can be overwritten to have any valid variables that one would want in the merged CSV.

# %% [markdown]
# ##### Python Processing
#
# Once the merged file exists, it can easily be copied from any server to anywere else using the `cp` command. Once it is on a computer that can be used for analysis (one that can run `matplotlib`, ect) the next method can be used: `ReadMergedCSV`.
#
# To use this method the python package: `netCDF4utils` has to be imported into the jupyter notebook to be used.
#
# It requires that a filepath and a dataframe be supplied so that it can know where the merged CSV is located and where it needs to put the resulting dataframe. This function is quite slow, since the way that the csv is stored requires that every array of values must be parsed for the correct values to be put into the dataframe.
#
# After this has been done the pandas dataframe can be manipulated easily, as with any other pandas dataframe.
#
# Some important things to note:
#
# 1. Many of the column data for many of the rows are themselves arrays, so plotting and analysis should be either done row by row or a relevant constant must be extracted to have all of the occultations analyzed together.
# 2. The data is not particularly clean, meaning that there are some significant artefacting problems that I have seen within the data that must be addressed before we can truly say that we have correct analysis of the data. This ranges from refractivity being set to -infinity to bending angles being close enough to zero at high impact parameters that the behavior of the curves is not particularly meaningful.
#
# There are some additional functions that be can used to analyze the data. These include averaging, exponential coefficient determination, data plotting, binned plotting, moving average plotting, and minimum and maximum finding. These all are designed to have functionality that seems to fit with finding trends in this particular data.
#
# To illustrate some of these functions and their utility, I will import a merged Dataset and manipulate it with the functions defined in the `netCDF4utils` package.

# %%
import netCDF4utils as utils
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mergeData = pd.DataFrame()
mergeData = utils.ReadMergedCSV('./merge2.txt',mergeData)
# Out:
# Converting Columns: occ_id
# Converting Columns: start_time
# Converting Columns: lat
# Converting Columns: lon
# Converting Columns: overall_qual
# Converting Columns: snr_L2p
# /Users/connereric2/Documents/GitHub/NetCDF4-Utils/netCDF4utils.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   mergeData[s][i]=temp
# Converting Columns: bangle
# Converting Columns: impact
# Converting Columns: impact_opt
# Converting Columns: refrac
# Converting Columns: alt_refrac
# Converting Columns: geop_refrac
# Converting Columns: undulation
# Converting Columns: r_coc
# Converting Columns: roc

# %% [markdown]
# The Dataframe has this structure:

# %%
mergeData
# Out:
#                                occ_id    start_time        lat         lon  \
# 0    OC_20180914083242_C006_G017_UCAR  5.902292e+08  32.265550 -119.311510
# 1    OC_20180914151413_C006_G021_UCAR  5.902533e+08  27.541508  151.155720
# 2    OC_20180914111128_C006_G027_UCAR  5.902387e+08 -50.504814   51.377235
# 3    OC_20180914201610_C006_G020_UCAR  5.902714e+08  70.508280  106.373020
# 4    OC_20180914230809_C006_G014_UCAR  5.902817e+08 -48.244183  -65.081580
# 5    OC_20180914062806_C006_G024_UCAR  5.902217e+08 -48.468850 -123.485016
# 6    OC_20180914081355_C006_G012_UCAR  5.902280e+08 -27.586235 -152.987930
# 7    OC_20180914215523_C006_G012_UCAR  5.902773e+08  25.409320   14.897665
# 8    OC_20180914190440_C006_G027_UCAR  5.902671e+08  29.472467 -153.107860
# 9    OC_20180914224603_C006_G018_UCAR  5.902804e+08 -25.216385 -176.953430
# 10   OC_20180914114652_C006_G029_UCAR  5.902408e+08   9.873280  169.687600
# ...

# %% [markdown]
# ##### Analysis: Artefacting
#
# I'm going to start with some of the artefacting problems with the data, since it will explain many of the things that functions require to work. The most common is errors in computing the refractivity of the occultation at different geopotentials. For example we see that for `OC_20190914061621_C006_G023_UCAR`:

# %%
utils.PlotRowArrays(mergeData,'refrac','geop_refrac',[137],True)
utils.PlotRowArrays(mergeData,'bangle','impact_opt',[137],True)

# %% [markdown]
# While normal occultations look approximately like this:

# %%
utils.PlotRowArrays(mergeData,'refrac','geop_refrac',[1,2],True)
utils.PlotRowArrays(mergeData,'bangle','impact_opt',[1,2],True)

# %% [markdown]
# The values on the larger side of the geopotential and impact parameter are obviously wrong, and there must have been a problem in the processing or collecting of the data. This can be accounted for (to a certain extent) by the average snr of the occultation. Below is a graph displaying the proportion of datasets which have this kind of artefact vs the average snr of the data. I tested whether this happens by seeing if the average refractivity of the column is < -1, since the refractivity should never be less than 0, and we can infer that there was a problem if the average of all of them is particularly negative.

# %%
def isnegrefrac(ref):
    if np.average(ref) < -1:
        return 1
    else :
        return 0

utils.AppendFunc(mergeData,'refrac', isnegrefrac, 'isnegrefrac')
utils.appendAvg(mergeData,'snr_L2p')

# %%
utils.AppendFunc(mergeData,'bangle',isnegrefrac,'isneg_')

# %%
utils.plotbindataaverage(mergeData,'avgsnr_L2p','isnegrefrac_refrac',0,600,50)
utils.plotbindataaverage(mergeData,'avgsnr_L2p','isneg__bangle',0,600,50)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# So its clear that these artefacts are a result of low snr. Thus it suggests that we should remove occultations with an average snr < ~210, since at that value the proportion of nonsensical refractivity data is 0. Additionally this isn't enough for the bending angle to act correctly, since that drops to 0 at around 375. All of the analysis code is equiped with a lower bound requirement for snr that can be set. The default for this value is usually set to 0. We also would like to know what number of the occultations are unfit for processing

# %%
minimumsnr = 210
print('Usable occultations: ' + str(np.size(np.where(mergeData.avgsnr_L2p > minimumsnr))))
utils.plotnuminbin(mergeData,'avgsnr_L2p',0,600,50)
# Out:
# No handles with labels found to put in legend.
# Usable occultations: 197

# %% [markdown]
# So of the 361 occultations, only 197 fit the snr requirements we have for meaningful data analysis. This is somewhat of a problem, given $> \frac{1}{3}$ of the data is not usable, however I guess it is what it is. The most prominent amount of occultations do have snr at ~275, so this is encouraging, though bending angle analysis will still require a very small number of runs.
#
# ##### Analysis: dlnRefrac
#
# One aspect of the data that is invariant accross all correctly processed data is an exponential decay to 0 for refractivity as a function of geopotential. To find the coefficient of the exponential we simply have to approximate the derivative (using the center differnce approach) and divide by the value of the refractivity at that point. So we suppose that $ref[i] = e^{\lambda geop[i]}$ and thus:
#
# $ \lambda = \frac{ref[i+1]-ref[i-1]}{ref[i]*(geop[i+1]-geop[i-1])} $

# %%
utils.appenddlnvar(mergeData,'refrac','geop_refrac',-np.inf,np.inf)

# %%
utils.plotbindataaverage(mergeData,'lat','dlnrefrac',minx=-90,maxx=90,binsize=10,minsnr=minimumsnr)
utils.plotbindataaverage(mergeData,'lon','dlnrefrac',minx=-180,maxx=180,binsize=20,minsnr=minimumsnr)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# So there are some clear trends in this parameter (which I should be completely clear about: I have no actual clue what the physical interpretation of it is.) The latitude gives an odd cubic shape to it, and the longitude has a very noisy graph. I personally would argue that the longitude should have very little to do with this parameter, since climates at the same latitude tend to be similar (which I can only suppose is related to the atmospheric conditions.) The latitude, however, should have an effect because there are climate differences at differing latitudes. To account for some of the noise it seems like it should be a good idea to look at the number of occultations at given latitudes/longitudes

# %%
utils.plotnuminbin(mergeData,xname='lat',maxx=90,minx=-90,binsize=10)
utils.plotnuminbin(mergeData,xname='lon',maxx=180,minx=-180,binsize=10)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# So its faily clear that much of the noise is a result of a lack of data at certain longitudes/latitudes.
#
# Next I looked for a relationship between this parameter and the snr. There was some indication of a relationship, however when we consider the number of occultations with the higher snr values, it looks like there is none.

# %%
utils.plotbindataaverage(mergeData,'avgsnr_L2p','dlnrefrac',minx=215,maxx=600,binsize=50,minsnr=minimumsnr-1)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### Analysis: min_alt_refrac
#
# Some other important parameters that we looked at in the past were the values minimum and maximum bending angles and the latitude at different minimum altitudes.

# %%
utils.AppendFunc(mergeData,fname='alt_refrac',func=np.min,funcname='min')
utils.AppendFunc(mergeData,fname='bangle',func=np.min,funcname='min')
utils.AppendFunc(mergeData,fname='bangle',func=np.max,funcname='max')

# %%
utils.plotbindataaverage(mergeData,xname='min_alt_refrac',yname='min_bangle',minsnr=375,minx=100,maxx=2750,binsize = 500)
# Out:
# No handles with labels found to put in legend.

# %%
utils.plotbindataaverage(mergeData,xname='min_alt_refrac',yname='max_bangle',minsnr=100,minx=100,maxx=2750,binsize = 100)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# I had to use significantly less data for the minimum, since most occultations have too low of snr for correct analysis of the bending angle, however I could use more for the max bending angle since artefacting only seems to set things to $-\infty$.
#
# The decline in bending angle makes complete sense, since there is a significant dropoff of refractivity at higher altitudes which gives a smaller bending angle.
#
# The minimum drops into negative because of another weird aspect of the data, illustrated here:

# %%
utils.PlotRowArrays(mergeData,'bangle','impact_opt',[90],True)

# %% [markdown]
# These dips in the bending angle can actually drop quite low, and even into negative numbers (which gives a negative average at the minimum. Additionally at higher impact parameter values there can be some weird oscillatory behavior that I suspect has to do with the numbers being very close to 0.
#
# I have no clue how to explain these dips, nor correct or account for them other than using higher snr, but I figured it was important to point out and they don't really make any sense.
#
# Now to move onto undulation analysis
#
# ##### Undulation analysis
#
# The first thing we want to check is how this changes with respect to latitude and longitude.

# %%
utils.plotbindataaverage(mergeData,'lat','undulation',minx=-90,maxx=90,binsize = 15, minsnr=215)
utils.plotbindataaverage(mergeData,'lon','undulation',minx=-180,maxx=180,binsize = 20, minsnr=215)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# The undulation also has some clear patterns. The longitude graph has a clear bell like shape that is 0 at the edges and is maximum at longitude = 0. The Latitude graph also that cubic like pattern that was seen in the $\lambda$ graph vs latitude. I suspect these to be related but really I don't know for certain.

# %%
utils.plotbindataaverage(mergeData,'min_alt_refrac','undulation',minx=0,maxx=3000,binsize = 200, minsnr=200)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# The Undulation looks like it has a dropping value as we approach 2400, however there is also a sharp increase there so I am not so sure what is going on there to be honest.
#
# ##### Ending remarks
#
# Some ending notes:
#
# The data is fairly messy. I don't know if this is because of the UCAR data or if the post processing procedure is not particularly robust or effective. This results in the analysis being fairly difficult for some parameters, such as bending angle. I suspect this might be a little of both, since the snr for all of these occultations is significantly less than the snr from the data you had me looking at on the sql server. The fact that the postprocessing doesn't recover the data particularly well when there is low snr is not particularly good, but this is perhaps just a fact of how recovering data from noisy data works.
#
# The ROC variable also has some relationship to latitude and longitude, but this makes sense since it is related to the curvature of the earth at that point, so I didn't feel the need to include it.
#
# The data analysis tools that I made are largely effective at calculating important quantities and visualizing data using graphs. The `AppendFunc` tool is fairly robust but could be expanded, for example. Future additions might be the ability to input multivariable functions and ignoring certain values based on the row's data.
#
# I used binned data to analyze much of what is going on, but I also have a scrubbing tool built in. The scrubbing tool I thought would be good for applying a lowpass filter to the data, thus reducing some noise. However, it seems like I do not have enough occultations for it to function particularly well, in fact in some cases it makes the data look more noisy.
#
# A lot of my time honestly was trying to find ways to recover data when there are problems in the processing. This proved to be a lot more difficult than I thought it would be. In the end removing rows based on snr seemed to be the best way to do this, however I was playing with the idea of just removing the $-\infty$ values and pretending the data was continuous there by projecting out data based on prior points. I wasn't sure about this approach, however, since occultations that had problems in one category tended to have them in many other categories, which led me to just figuring I should throw them out.
#
# Also I realized at the very end that I forgot to grab `drytemp` from the post processed NetCDF4 files, I can do that now but I probably won't be home till late and you will have to wait for it to be tomorrow/later.
